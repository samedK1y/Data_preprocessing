# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# Eksik veri kontrolü:

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# İstatistiksel özete bakarak aykırı değer olma olasılığındaki verilerin aykırı değer kontrolü:

# %%
Q1_chl = df['chol'].quantile(0.25)
Q3_chl = df['chol'].quantile(0.75)
IQR_chl = Q3_chl - Q1_chl

alt_sinir_chl = Q1_chl - 1.5*IQR_chl
ust_sinir_chl = Q3_chl + 1.5*IQR_chl

print(f"Kolestrol icin ust sinir: {ust_sinir_chl}")
print(f"Bu değerden büyük olanlar aykiri: {df[df['chol'] > ust_sinir_chl]['chol'].values}")

plt.figure(figsize = (3,3))
sns.boxplot(x = df['chol'], color= 'skyblue')
plt.title("Kolestrolun aykiri degeri")
plt.show()
# Out:
# Kolestrol icin ust sinir: 371.0
# Bu değerden büyük olanlar aykiri: [417 564 409 564 394 407 564 407 394 394 409 417 407 407 417 409]

# %%
Q1_bst = df['trestbps'].quantile(0.25)
Q3_bst = df['trestbps'].quantile(0.75)
IQR_bst = Q3_bst - Q1_bst

alt_sinir_bst = Q1_bst - 1.5 * IQR_bst
ust_sinir_bst = Q3_bst + 1.5 * IQR_bst  

print(f"Tresebst için üst sinir değer: {ust_sinir_bst}")
print(f"Tresebst için aykiri değerler: {df[df['trestbps'] > ust_sinir_bst]['trestbps'].values}")

plt.figure(figsize= (3,3))
sns.boxplot(x = df['trestbps'], color="skyblue")
plt.title("Trestbps için aykirilik kontrolü")
plt.show()
# Out:
# Tresebst için üst sinir değer: 170.0
# Tresebst için aykiri değerler: [180 178 174 180 192 200 178 192 180 200 192 172 180 174 178 180 200 180
#  178 180 178 174 180 200 172 180 178 178 172 180]

# %%
Q1_tha = df['thalach'].quantile(0.25)
Q3_tha = df['thalach'].quantile(0.75)
IQR_tha = Q3_tha - Q1_tha

alt_sinir_tha = Q1_tha - 1.5 *IQR_tha
ust_sinir_tha = Q3_tha + 1.5 *IQR_tha

print(f"Thalach için üst sinir değer: {ust_sinir_tha}")
print(f"Thalach için aykiri değerler: {df[df['thalach'] > ust_sinir_tha]['thalach'].values}")
# Out:
# Thalach için üst sinir değer: 217.0
# Thalach için aykiri değerler: []

# %% [markdown]
# Aykırı değerleri bastırma:

# %%
column_chl = 'chol'
df[column_chl] = df[column_chl].clip(alt_sinir_chl,ust_sinir_chl)
print(f"{column_chl} aykiri değerleri baskılandı.")

plt.figure(figsize = (2,2))
sns.boxplot(x = df['chol'], color= 'skyblue')
plt.title("Chol yeni deger grafiği")
plt.show()
# Out:
# chol aykiri değerleri baskılandı.

# %%
column_bst = 'trestbps'
df[column_bst] = df[column_bst].clip(alt_sinir_bst,ust_sinir_bst)

print(f"{column_bst} aykiri degerleri baskilandi")

plt.figure(figsize = (3,3))
sns.boxplot(x = df['trestbps'], color= 'skyblue')
plt.title("Tresbst yeni deger grafiği")
plt.show()
# Out:
# trestbps aykiri degerleri baskilandi

# %% [markdown]
# Veriyi parçalama:

# %%
from sklearn.model_selection import train_test_split

X = df.drop('target',axis= 1)
y = df['target']

X_train ,X_test, y_train , y_test = train_test_split(X,y, test_size= 0.20 , random_state= 42)

print(f"Toplam veri sayisi {len(df)}")
print(f"Eğitim seti: {len(X_train)} | Test seti: {len(X_test)}")
# Out:
# Toplam veri sayisi 1025
# Eğitim seti: 820 | Test seti: 205

# %% [markdown]
# Normalizasyon uygulama:

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train)   # sadece train öğrenir
X_test = scaler.transform(X_test)         # test'e uygular
